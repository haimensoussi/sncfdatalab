# %%
df_analytics = (
    df_curated.groupBy("DepartureCity")
    .avg("DelayMinutes")
    .withColumnRenamed("avg(DelayMinutes)", "AverageDelay")
)

display(df_analytics)

df_analytics.write.format("delta").mode("overwrite").saveAsTable("sncf_trafic_dev.analytics.delay_by_city")

print("✅ Table Analytics créée : sncf_trafic_dev.analytics.delay_by_city")

# %%
train_status_df = spark.sql("SELECT * FROM sncf_trafic_dev.curated.train_status")

# %%
df_analytics = (
    train_status_df.groupBy("DepartureStation")
    .avg("DelayMinutes")
    .withColumnRenamed("avg(DelayMinutes)", "AverageDelay")
)

display(df_analytics)

df_analytics.write.format("delta").mode("overwrite").saveAsTable("sncf_trafic_dev.analytics.delay_by_city")

print("✅ Table Analytics créée : sncf_trafic_dev.analytics.delay_by_city")

# %%
# %sql
SHOW TABLES IN sncf_trafic_dev.raw;
SHOW TABLES IN sncf_trafic_dev.curated;
SHOW TABLES IN sncf_trafic_dev.analytics;

# %%
agg_df = (
    spark.table("sncf_trafic_dev.curated.train_status")
    .groupBy("DepartureStation")
    .agg(
        {"DelayMinutes": "avg", "TrainID": "count"}
    )
    .withColumnRenamed("avg(DelayMinutes)", "AverageDelay")
    .withColumnRenamed("count(TrainID)", "TrainCount")
)

display(agg_df)

agg_df.write.format("delta").mode("overwrite").saveAsTable("sncf_trafic_dev.analytics.train_status_aggregates")
# Out:
# Databricks visualization. Run in Databricks to view.
